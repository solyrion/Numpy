# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 폰트 설정
import os
if os.name == 'posix':
    plt.rc('font', family = "AppleGothic")
else:
    plt.rc('font', family = "malgun Gothic")
plt.rc("axes", unicode_minus = False)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/medical_201909.csv.zip", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %% [markdown]
# ### Q1

# %%
df[df['상권업종소분류명'] == '약국']['시도명'].value_counts()
# Out:
# 경기도        4510
# 서울특별시      3579
# 부산광역시      1130
# 경상남도       1017
# 인천광역시      1002
# 경상북도        915
# 대구광역시       870
# 전라북도        862
# 충청남도        830
# 전라남도        811
# 강원도         729
# 광주광역시       691
# 충청북도        648
# 대전광역시       603
# 울산광역시       362
# 제주특별자치도     226
# 세종특별자치시      99
# Name: 시도명, dtype: int64

# %% [markdown]
# ### Q2

# %%
df_vet = df[df['상권업종소분류명'] == '동물병원']['시도명'].value_counts()
df_vet
# Out:
# 경기도        992
# 서울특별시      557
# 인천광역시      193
# 경상북도       165
# 경상남도       161
# 부산광역시      153
# 충청남도       131
# 대구광역시      119
# 전라북도       111
# 강원도         85
# 대전광역시       77
# 전라남도        77
# 충청북도        75
# 광주광역시       71
# 울산광역시       61
# 제주특별자치도     46
# 세종특별자치시     13
# Name: 시도명, dtype: int64

# %%
df_vet.plot.barh()

# %%
k = df[df['상권업종소분류명'] == '동물병원']

plt.figure(figsize = (12, 8))
sns.countplot(data = k, y = '시도명', order = k['시도명'].value_counts().index)

# %% [markdown]
# ### Q3

# %%
df2 = df[(df['시도명'] == '서울특별시')
        & (df['상권업종중분류명'] == '병원')].copy()

df3 = df2[(df2['상권업종소분류명'].str.contains('피부')) | 
   (df2['상권업종소분류명'].str.contains('성형'))].copy()


k = df3['시군구명'].value_counts() / df2['시군구명'].value_counts()

# %%
ans = k.sort_values(ascending = False).round(2)
ans
# Out:
# 강남구     0.24
# 서초구     0.17
# 마포구     0.09
# 서대문구    0.08
# 영등포구    0.08
# 강동구     0.07
# 중구      0.07
# 중랑구     0.07
# 강서구     0.07
# 양천구     0.07
# 송파구     0.06
# 광진구     0.06
# 은평구     0.06
# 성북구     0.06
# 구로구     0.06
# 금천구     0.05
# 노원구     0.05
# 성동구     0.05
# 강북구     0.05
# 용산구     0.05
# 관악구     0.04
# 동대문구    0.04
# 동작구     0.04
# 종로구     0.03
# 도봉구     0.02
# Name: 시군구명, dtype: float64

# %% [markdown]
# ### Q4

# %%
df_old = df[df['상권업종소분류명'] == '노인/치매병원'].copy()

# %%
import folium

# %%
map = folium.Map(location = [df_old['위도'].mean(), df_old['경도'].mean()]
                , zoom_start = 6)

for n in df_old.index:
    name = df_old.loc[n, '상호명']
    address = df_old.loc[n, '도로명주소']
    popup = f"{name}-{address}"
    location = [df_old.loc[n, '위도'], df_old.loc[n, '경도']]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
