# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 폰트 설정
import os
if os.name == 'posix':
    plt.rc('font', family = "AppleGothic")
else:
    plt.rc('font', family = "malgun Gothic")
plt.rc("axes", unicode_minus = False)

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/corazzon/boostcourse-ds-510/master/data/medical_201909.csv.zip", low_memory=False)
df.shape
# Out:
# (91335, 39)

# %% [markdown]
# ### Q1

# %%
df[df['상권업종소분류명'] == '약국']['시도명'].value_counts()
# Out:
# 경기도        4510
# 서울특별시      3579
# 부산광역시      1130
# 경상남도       1017
# 인천광역시      1002
# 경상북도        915
# 대구광역시       870
# 전라북도        862
# 충청남도        830
# 전라남도        811
# 강원도         729
# 광주광역시       691
# 충청북도        648
# 대전광역시       603
# 울산광역시       362
# 제주특별자치도     226
# 세종특별자치시      99
# Name: 시도명, dtype: int64

# %% [markdown]
# ### Q2

# %%
df_vet = df[df['상권업종소분류명'] == '동물병원']['시도명'].value_counts()
df_vet
# Out:
# 경기도        992
# 서울특별시      557
# 인천광역시      193
# 경상북도       165
# 경상남도       161
# 부산광역시      153
# 충청남도       131
# 대구광역시      119
# 전라북도       111
# 강원도         85
# 대전광역시       77
# 전라남도        77
# 충청북도        75
# 광주광역시       71
# 울산광역시       61
# 제주특별자치도     46
# 세종특별자치시     13
# Name: 시도명, dtype: int64

# %%
plt.figure(figsize = (12, 8))
plt.xticks(rotation = 30)

df_vet.plot.barh()

# %%
sns.countplot(data = df[df['상권업종소분류명'] == '동물병원'], y = '시도명')

# %% [markdown]
# ### Q3

# %%
df2 = df[(df['시도명'] == '서울특별시')
        & (df['상권업종중분류명'] == '병원')].copy()

df3 = df2[(df2['상권업종소분류명'].str.contains('피부')) | 
   (df2['상권업종소분류명'].str.contains('성형'))].copy()


k = df3['시군구명'].value_counts() / df2['시군구명'].value_counts()

# %%
ans = k.sort_values(ascending = False).round(2)
ans
# Out:
# 강남구     0.24
# 서초구     0.17
# 마포구     0.09
# 서대문구    0.08
# 영등포구    0.08
# 강동구     0.07
# 중구      0.07
# 중랑구     0.07
# 강서구     0.07
# 양천구     0.07
# 송파구     0.06
# 광진구     0.06
# 은평구     0.06
# 성북구     0.06
# 구로구     0.06
# 금천구     0.05
# 노원구     0.05
# 성동구     0.05
# 강북구     0.05
# 용산구     0.05
# 관악구     0.04
# 동대문구    0.04
# 동작구     0.04
# 종로구     0.03
# 도봉구     0.02
# Name: 시군구명, dtype: float64

# %% [markdown]
# ### Q4

# %%
df_old = df[df['상권업종소분류명'] == '노인/치매병원'].copy()

# %%
import folium

# %%
map = folium.Map(location = [df_old['위도'].mean(), df_old['경도'].mean()]
                , zoom_start = 6)

for n in df_old.index:
    name = df_old.loc[n, '상호명']
    address = df_old.loc[n, '도로명주소']
    popup = f"{name}-{address}"
    location = [df_old.loc[n, '위도'], df_old.loc[n, '경도']]
    folium.Marker(
        location = location,
        popup = popup,
    ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c85d73fd3ba9dd8aae3a4521ec9c20b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c85d73fd3ba9dd8aae3a4521ec9c20b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c85d73fd3ba9dd8aae3a4521ec9c20b6 = L.map(
#                 &quot;map_c85d73fd3ba9dd8aae3a4521ec9c20b6&quot;,
#                 {
#                     center: [36.32263841022539, 127.6921615663797],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87bf369afa41b559fda737958ad8d090 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c85d73fd3ba9dd8aae3a4521ec9c20b6);
#
#
#             var marker_a157de90f5276a123ae6c782b3649111 = L.marker(
#                 [35.209153957476104, 129.040772964856],
#                 {}
#             ).addTo(map_c85d73fd3ba9dd8aae3a4521ec9c20b6);
#
#
#         var popup_ab5b895b6a9911e725b9042bfae1728c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eed30950ae18976fcbf58bc65cb61a7f = $(`&lt;div id=&quot;html_eed30950ae18976fcbf58bc65cb61a7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;다사랑요양병원-부산광역시 북구 덕천로 339&lt;/div&gt;`)[0];
#                 popup_ab5b895b6a9911e725b9042bfae1728c.setContent(html_eed30950ae18976fcbf58bc65cb61a7f);
#
#
#
#         marker_a157de90f5276a123ae6c782b3649111.bindPopup(popup_ab5b895b6a9911e725b9042bfae1728c)
#         ;
#
#
#
#
#             var marker_bab4b182c70da4cfadbac39caa14d98c = L.marker(
#                 [34.986584856872504, 127.746980976467],
#                 {}
#             ).addTo(map_c85d73fd3ba9dd8aae3a4521ec9c20b6);
#
#
#         var popup_3e558eca970b608a20040a0060e69da5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f447ead1629376e8a7f29a62407b88b0 = $(`&lt;div id=&quot;html_f447ead1629376e8a7f29a62407b88b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;노경회-전라남도 광양시 진월면 용소길 7&lt;/div&gt;`)[0];
#                 popup_3e558eca970b608a20040a0060e69da5.setContent(html_f447ead1629376e8a7f29a62407b88b0);
#
#
#
#         marker_bab4b182c70da4cfadbac39caa14d98c.bindPopup(popup_3e558eca970b608a20040a0060e69da5)
#         ;
#
#
#
#
#             var marker_9f11b1f4ebd7aa9c30bfab6eb2734a26 = L.marker(
#                 [37.6936890859817, 126.78012152336599],
#                 {}
#             ).addTo(map_c85d73fd3ba9dd8aae3a4521ec9c20b6);
#
#
#         var popup_cc3988343d30b646a85fd08f690c3725 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9f48bd330110c2f7d0758491dbc93ba = $(`&lt;div id=&quot;html_a9f48bd330110c2f7d0758491dbc93ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;일산카네이션너싱홈-경기도 고양시 일산동구 중산로 241&lt;/div&gt;`)[0];
#                 popup_cc3988343d30b646a85fd08f690c3725.setContent(html_a9f48bd330110c2f7d0758491dbc93ba);
#
#
#
#         marker_9f11b1f4ebd7aa9c30bfab6eb2734a26.bindPopup(popup_cc3988343d30b646a85fd08f690c3725)
#         ;
#
#
#
#
#             var marker_66edf0dd70ef8859294118d72f9b1629 = L.marker(
#                 [34.991014089798306, 127.460606294325],
#                 {}
#             ).addTo(map_c85d73fd3ba9dd8aae3a4521ec9c20b6);
#
#
#         var popup_c1178e30979404289ba52549127ef98a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f5341d9e1fff33955e58c000903f298 = $(`&lt;div id=&quot;html_5f5341d9e1fff33955e58c000903f298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;은성복지회-전라남도 순천시 조비길 298&lt;/div&gt;`)[0];
#                 popup_c1178e30979404289ba52549127ef98a.setContent(html_5f5341d9e1fff33955e58c000903f298);
#
#
#
#         marker_66edf0dd70ef8859294118d72f9b1629.bindPopup(popup_c1178e30979404289ba52549127ef98a)
#         ;
#
#
#
#
#             var marker_0005082fb6fa4d1fbfc645e3e55db184 = L.marker(
#                 [36.3651320905281, 128.295523973833],
#                 {}
#             ).addTo(map_c85d73fd3ba9dd8aae3a4521ec9c20b6);
#
#
#         var popup_7d4168a9648fcb14f3328a1b55bf5f58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4fab5aa1ad0cbb97100af476076ee79f = $(`&lt;div id=&quot;html_4fab5aa1ad0cbb97100af476076ee79f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;하은실버홈-경상북도 상주시 낙동면 영남제일로 125-17&lt;/div&gt;`)[0];
#                 popup_7d4168a9648fcb14f3328a1b55bf5f58.setContent(html_4fab5aa1ad0cbb97100af476076ee79f);
#
#
#
#         marker_0005082fb6fa4d1fbfc645e3e55db184.bindPopup(popup_7d4168a9648fcb14f3328a1b55bf5f58)
#         ;
#
#
#
#
#             var marker_6f53d0b93be8a0a3c48f2a84e18cf866 = L.marker(
#                 [36.8
